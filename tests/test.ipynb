# %%
# %pdb off
import pe
V = pe.PECharVariety('m016')
V.show()
# Out:
# Automatic pdb calling has been turned OFF
# Using nbAgg as the matplotlib backend.
# Loaded the base fiber from PE_base_fibers/m016.base
# Order is 169; Degree is 6.
# Using: radius=1.02; tight_radius=1
# Elevating the R-path with base index 73.
# Tracked in 2.08 seconds.
# Computing longitude holonomies and eigenvalues ...
# Using index 0 to determine signs.
# Polishing the end fibers ...
# Checking for completeness ...
# OK. Lifts close up.
# Tightening the circle to radius 1
# Computing longitude holonomies and eigenvalues ...
# Using index 0 to determine signs.
# <img src="data:image/png;base64,..." width="794.4">

# %%
L = pe.EllipticSL2RLifter(V)
L.show()
# Out:
# polishing shapes ... (6.94 secs)
# lifting reps ... (7.30 secs)
# computing translations ... (7.20 secs)
# <img src="data:image/png;base64,..." width="818.4">

# %%
R = pe.PRCharVariety('m016')
R.show()
# Out:
# Choosing random base index: 25
# Computing the base fiber ...  done. (0.014 seconds)
# Would you like to save this base fiber? (y/n)y
# Saved base fiber as PR_base_fibers/m016.base
# Order is 128; Degree is 6.
# Using offset=0.02
# Elevating the R-path with base index 25.
# Tracked in 1.48 seconds.
# Computing longitude holonomies and eigenvalues ...
# Using index 0 to determine signs.
# Tightening to the real axis.
# Computing longitude holonomies and eigenvalues ...
# Using index 0 to determine signs.
# <img src="data:image/png;base64,..." width="720">
